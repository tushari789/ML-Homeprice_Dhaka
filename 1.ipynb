# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('homedata.csv')

# %%
df
# Out:
#    area   price
# 0  2600   55000
# 1  3000   56900
# 2  3600   68000
# 3  4000   72000
# 4  5000   71000
# 5  2500   40000
# 6  2700   38000
# 7  1200   17000
# 8   500  100000

# %%
df.head()
# Out:
#    area  price
# 0  2600  55000
# 1  3000  56900
# 2  3600  68000
# 3  4000  72000
# 4  5000  71000

# %%
df.head(4)
# Out:
#    area  price
# 0  2600  55000
# 1  3000  56900
# 2  3600  68000
# 3  4000  72000

# %%
df.shape
# Out:
# (9, 2)

# %%
df.isnull().any()
# Out:
# area     False
# price    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
x= df[['area']]
y = df['price']

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3600
# 3  4000
# 4  5000
# 5  2500
# 6  2700
# 7  1200
# 8   500

# %%
y
# Out:
# 0     55000
# 1     56900
# 2     68000
# 3     72000
# 4     71000
# 5     40000
# 6     38000
# 7     17000
# 8    100000
# Name: price, dtype: int64

# %% [markdown]
# # visualization

# %%
plt.scatter(df['area'], df['price'], marker='+', color= 'red')
plt.xlabel('Area in squre ft')
plt.ylabel('Price in taka')
plt.title('Homepricess is Dhaka')
# Out:
# Text(0.5, 1.0, 'Homepricess is Dhaka')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mc\\Desktop\\Data file'

# %%
df.head()
# Out:
#    area  price
# 0  2600  55000
# 1  3000  56900
# 2  3600  68000
# 3  4000  72000
# 4  5000  71000

# %%
df
# Out:
#    area   price
# 0  2600   55000
# 1  3000   56900
# 2  3600   68000
# 3  4000   72000
# 4  5000   71000
# 5  2500   40000
# 6  2700   38000
# 7  1200   17000
# 8   500  100000

# %%
plt.scatter(df['area'], df['price'], marker='+', color= 'red')
plt.xlabel('Area in squre ft')
plt.ylabel('Price in taka')
plt.title('Homepricess is Dhaka')
# Out:
# Text(0.5, 1.0, 'Homepricess is Dhaka')

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest= train_test_split(x, y, test_size= .30, random_state=1)

# %%
xtrain
# Out:
#    area
# 7  1200
# 1  3000
# 0  2600
# 4  5000
# 3  4000
# 5  2500

# %%
ytrain
# Out:
# 7    17000
# 1    56900
# 0    55000
# 4    71000
# 3    72000
# 5    40000
# Name: price, dtype: int64

# %%
ytrain
# Out:
# 7    17000
# 1    56900
# 0    55000
# 4    71000
# 3    72000
# 5    40000
# Name: price, dtype: int64

# %%
ytest
# Out:
# 8    100000
# 2     68000
# 6     38000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg= LinearRegression()

# %%
reg.fit (xtrain,ytrain)
# Out:
# LinearRegression()

# %%
reg.predict(xtest)
# Out:
# array([14831.88573634, 59996.39065817, 46884.11503571])

# %%
reg.predict(xtrain)
# Out:
# array([25030.3223316 , 51254.87357653, 45427.1955221 , 80393.26384868,
#        65824.0687126 , 43970.27600849])

# %%
plt.scatter(df['area'], df['price'], marker='+', color= 'orange')
plt.xlabel('Area in squre ft')
plt.ylabel('Price in taka')
plt.title('Homepricess is Dhaka')
plt.plot(df.area, reg.predict(df[['area']]))

# %%
reg.predict([[3000]])
# Out:
# array([51254.87357653])

# %%
reg.predict([[3500]])
# Out:
# array([58539.47114457])

# %%
import pickle as pk

# %%
pk.dump(reg, open('My work', 'wb'))
